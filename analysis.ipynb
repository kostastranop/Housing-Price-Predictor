# %%
# Import libs
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
# Load data
df = pd.read_csv("housing.csv")

# %%
# Basic Inspection
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
df.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  str
# dtypes: float64(9), str(1)
# memory usage: 1.6 MB

# %%
# Replace missing values
from sklearn.impute import SimpleImputer

imputer = SimpleImputer()
df["total_bedrooms"] = imputer.fit_transform(df[["total_bedrooms"]])

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20640 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  str
# dtypes: float64(9), str(1)
# memory usage: 1.6 MB

# %%
# Split into train and test sets
from sklearn.model_selection import train_test_split

X = df.drop(columns=["median_house_value"])
y = df["median_house_value"]

x_train,x_test,y_train,y_test = train_test_split(X,y, test_size=0.20)

# %%
# Join the train set back
train_data = x_train.join(y_train)

# %%
# Histograms
train_data.hist(figsize=(15,8))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
# Check correlation heatmap
corr = train_data.corr(numeric_only=True)
fig,ax = plt.subplots(figsize=(15,8))
sns.heatmap(corr, annot=True, ax=ax)
# Out:
# <Axes: >

# %%
# Fix distribution for skewed features
def fix_dstribution(data):
    data["total_rooms"] = np.log(data["total_rooms"] +1)
    data["total_bedrooms"] = np.log(data["total_bedrooms"] +1)
    data["population"] = np.log(data["population"] +1)
    data["households"] = np.log(data["households"] +1)

fix_dstribution(train_data)

# %%
train_data.hist(figsize=(15,8))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
train_data["ocean_proximity"].value_counts()
# Out:
# ocean_proximity
# <1H OCEAN     7329
# INLAND        5191
# NEAR OCEAN    2146
# NEAR BAY      1843
# ISLAND           3
# Name: count, dtype: int64

# %%
# One hot encode categorical feature
def one_hot_encode(data):
    return data.join(pd.get_dummies(data.ocean_proximity)).drop(["ocean_proximity"], axis=1)

train_data = one_hot_encode(train_data)

# %%
train_data.head()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 4390     -118.26     34.07                28.0     6.363028        5.220356
# 11664    -118.03     33.85                30.0     7.749753        6.107023
# 15823    -122.42     37.75                52.0     7.383989        6.236370
# 16153    -122.48     37.78                50.0     7.677864        6.082219
# 917      -121.97     37.52                23.0     8.502283        6.855409
#
#        population  households  median_income  median_house_value  <1H OCEAN  \
# 4390     6.513230    5.313206         2.6250            187500.0       True
# 11664    7.268920    6.115892         4.0865            203700.0       True
# 15823    7.052721    6.086775         2.2328            250000.0      False
# 16153    7.013915    6.035481         3.5588            346400.0      False
# 917      7.836370    6.796824         5.0824            230900.0       True
#
#        INLAND  ISLAND  NEAR BAY  NEAR OCEAN
# ...

# %%
# Check new correlation heatmap
corr = train_data.corr(numeric_only=True)
fig,ax = plt.subplots(figsize=(15,8))
sns.heatmap(corr, annot=True, ax=ax)
# Out:
# <Axes: >

# %%
# Scatter plot to "map" california
plt.figure(figsize=(15,8))
sns.scatterplot(x="latitude", y="longitude", data=train_data, hue="median_house_value", palette="coolwarm")
# Out:
# <Axes: xlabel='latitude', ylabel='longitude'>

# %%
# Feature engineering
def feature_engineer(data):
    data["bedroom_ratio"] = data["total_bedrooms"] / data["total_rooms"]
    data["household_rooms"] = data["total_rooms"] / data["households"]

feature_engineer(train_data)

# %%
# Check correlation with new features
corr = train_data.corr(numeric_only=True)
fig,ax = plt.subplots(figsize=(15,8))
sns.heatmap(corr, annot=True, ax=ax)
# Out:
# <Axes: >

# %%
# Scale data
from sklearn.preprocessing import StandardScaler

def scale(data):
    x = data.drop(columns=["median_house_value"])
    y = data["median_house_value"]

    scaler = StandardScaler()
    x_data = scaler.fit_transform(x)
    y_data = y.to_numpy()

    return x_data,y_data

x_train,y_train = scale(train_data)

# %%
# Run the test set through the pipeline
test_set = x_test.join(y_test)
fix_dstribution(test_set)
test_set = one_hot_encode(test_set)
feature_engineer(test_set)
x_test,y_test = scale(test_set)

# %%
# Linear regression model
from sklearn.linear_model import LinearRegression

reg = LinearRegression()
reg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
# Score on test set
reg.score(x_test,y_test)
# Out:
# 0.6612674357427824

# %%
# Train random forest regressor model
from sklearn.ensemble import RandomForestRegressor

forest = RandomForestRegressor()
forest.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %%
forest.score(x_test,y_test)
# Out:
# 0.7892802202538358

# %%
# Random forest with CV
from sklearn.model_selection import GridSearchCV

forest = RandomForestRegressor(n_estimators=80)

param_grid = {
    "max_features": [1.0,0.33,"sqrt"],
    "max_depth": [None,10,20],
    "min_samples_split": [2,5,10],
    "min_samples_leaf": [1,2,4]
}

grid_search = GridSearchCV(forest, param_grid, cv=5, scoring="neg_mean_squared_error", return_train_score=True, n_jobs=-1, verbose=2)
grid_search.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 81 candidates, totalling 405 fits
# GridSearchCV(cv=5, estimator=RandomForestRegressor(n_estimators=80), n_jobs=-1,
#              param_grid={'max_depth': [None, 10, 20],
#                          'max_features': [1.0, 0.33, 'sqrt'],
#                          'min_samples_leaf': [1, 2, 4],
#                          'min_samples_split': [2, 5, 10]},
#              return_train_score=True, scoring='neg_mean_squared_error',
#              verbose=2)

# %%
# Get the best parameters and fit with bigger forest
best_params = grid_search.best_params_
best_params["n_estimators"] = 300
model = RandomForestRegressor(**best_params)

model.fit(x_train,y_train)
# Out:
# RandomForestRegressor(min_samples_leaf=2, min_samples_split=5, n_estimators=300)

# %%
model.score(x_test,y_test)
# Out:
# 0.7904672381705629

# %%
# Train the model on all the available data
fix_dstribution(df)
final_set = one_hot_encode(df)
feature_engineer(final_set)
x_final,y_final = scale(final_set)

final_model = RandomForestRegressor(**best_params)

final_model.fit(x_final,y_final)
# Out:
# RandomForestRegressor(min_samples_leaf=2, min_samples_split=5, n_estimators=300)

# %%
# Save the final model
import pickle

filename = "productionmodel.sav"
pickle.dump(final_model,open(filename,"wb"))
